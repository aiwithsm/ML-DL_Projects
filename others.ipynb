# %% [markdown]
# ```
# Arrays,Arrays - Interger data type and can be multi dimensional
# Tuple,"tuple - similar to list, but created in (), not mutable (Mutable - can be updated/Changed)"
# List,"List - similar to tuple, but created in [], mutable. Can have Integer or string, 1Dimentional, nested list can be multi dimensional"
# DataFrame,"Series - 1D dataframe is called series, Index of our own type; Dataframe - 2D table, more like SQL table, can have multiple data type data's"
# Dictionary,Dictionary - creating data with data and column names will be dictionary. Next step its converted to Dataframe
# ```

# %%
import pandas as pd
import numpy as np

a1 = (1,2) # Tuple will be in round braces, not mutable - cannot be changed
aa1 = ('a','bb') # tuple can also have strings, similar to list
a2 = [1,2] # List will be in squared braced, mutable. Can have integers and strings

mylist = list['abcdefghijklmnopqrstuvwxyz']
np.arange(6)

fruit = 'apple'
print(fruit)
print(5+4)
print('apple')
fruit[0:4] # 0 to n-1 position in the variable
type(fruit) # str

num=2
type(num) # int

# this is a single line comment

""" multi line comments """

text = input("get input from user")

sentence1  = "she said, \"that's Use backslash to use both types of quotation marks\""
print(sentence1)
sentence2 = 'she said, "that\'s Use backslash to use both thypes of quotation marks"'
print(sentence2)
sentence3 = 'she said, that\'s Use backslash to use both thypes of quotation marks'
print(sentence3)

animals = ['man','bear','pig']
type(animals)
print(animals.index('bear')) # returns index number 0,1,2 # output = 1
# animals.index('cat') # returns error as cat not found

# exception handling

try:
    cat_index = animals.index('cat')
except:
        cat_index = 'No cat found'
print(cat_index)

print('I'+'Love'+'python') # string concatenation
print('I'*10) # I printed 10 times
name = 3
print ('I'+str(name))

# %%
print('I {} Python'.format('love')) # Placeholder in print statement
print('I {} {}'.format('love','python'))
print('I {0} {1}, {1} {0}s me'.format('love','python'))
print('{0:8} | {1:8}'.format('apples','oranges')) # this can be used to create tables
print('{0:8} | {1:<8.2f}'.format('apples',2)) #gives 2.00, < is left aligned, .2f is 2 float values

print('               {}'.format('_'*5))
print('               <{}>'.format('santhosh'))

# Booleans

bool_1 = True
bool_2 = False

1==2

37> 29 and 37<40

# order of operations
not
and
or

# Conditional

if 45 > 59:
    print("working")
elif 45 == 45:
    print("elif executing")
else:
    print("else executing")
print("outside if loop")

# Functions

# DRY concept - Dont repeat yourself

def say_hi():
    print('HI')
say_hi() # call function

help(say_hi)

# %%
# Practice exercise

def user_input():
    text1 = input("enter the first word :")
    return text1
out_text1 = user_input()
print("The capital of india is {} and its not, its union territory".format(out_text1))

# Practice exercise 2

miles1 = input("How many kms you want to travel ?")
miles = int(miles1)
if miles < 3:
    print("Start walking !")
elif miles < 300:
    print("Drive!")
elif miles >= 300:
    print("fly")
else:
    print('NA')

# Practice exercise 3

charge = 0.51
print("Charge per day",charge * 24)
print("Charge per month",charge * 24 * 30)

print(918/(charge * 24))

# %%
# List

list_name = ['a','b','c']
# list_name = [] # empty list
list_name[0]
list_name[0] = 'd'
list_name
list_name[-1]

list_name.append('e')
list_name.extend(['x','y'])
ext = ['m','n']
list_name.extend(ext)
list_name

list_name.insert(0,'aa')
list_name.insert(2,'bb')
list_name

list_name[1:2]
list_name[0:2]
list_name[:2]
list_name[-2:] # last two

# %%
# LOOPS

animals = ['man','cat','bear']
for x in animals:
    print(x.upper())

index = 0
while index < len(animals):
    print(animals[index].upper())
    index += 1

# Sorting & Ranges

for number in range(5):
    print(number)

for number in range(0,5,2):
    print(number)

list = ['a','b']

for numb in list:
    xx = input("Enter to do list : ")
    list.append(xx)
    print(list)

# %%
# FILES

hosts = open('c:\Log\Messages\sample.txt')
hosts_content = hosts.read() # reads content
seek(offset) # change position to offset

hosts.seek(0) # start of the file
hosts.seek(5) # 5th byte, 5th character
hosts.read(3)
hosts.tell() # current position
hosts.close() # close the file
hosts.closed # says true or false ,whether file closed or open

# to automatically close use with condition

with open(file_path) as hosts:
    print(hosts.read())
print("File automatically closed aafter ending with statement")

with open(path) as hosts:
    for line in hosts:
        print(line) # print line by line, but has 2 line spaces between lines

with open(path) as hosts:
    for line in hosts:
        print(line.rstrip()) # print line by line, but removes line spaces between lines

# File modes

open(path,mode)

r - read(default)
w - write
x - create new file and write
a - write, append to existing data
+ - read & write to same file
b - binary eg: image file, compressed
t - text (default)

with open(path,'w') as hosts:
    hosts.write("santhosh")
    hosts.write("kumar")
    # output - santhoshkumar - printed in same line use \n for new line

# %%
# Practice Exercise

with open('untitled.txt') as hosts:
     hosts.seek(0)
    for line in hosts:
        print(hosts.tell())
